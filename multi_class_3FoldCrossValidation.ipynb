# %%
#cucumber 3
import numpy as np 
import pandas as pd
import os
import cv2
import matplotlib.pyplot as plt
from tqdm import tqdm
from random import shuffle
from keras.utils  import to_categorical
from sklearn.model_selection import KFold, StratifiedKFold

# %%
def get_random_eraser(p=0.5, s_l=0.02, s_h=0.4, r_1=0.3, r_2=1/0.3, v_l=0, v_h=255, pixel_level=False):
    def eraser(input_img):
        
        if input_img.ndim == 3:
            img_h, img_w, img_c = input_img.shape
        elif input_img.ndim == 2:
            img_h, img_w = input_img.shape

        p_1 = np.random.rand()

        if p_1 > p:
            return input_img

        while True:
            s = np.random.uniform(s_l, s_h) * img_h * img_w
            r = np.random.uniform(r_1, r_2)
            w = int(np.sqrt(s / r))
            h = int(np.sqrt(s * r))
            left = np.random.randint(0, img_w)
            top = np.random.randint(0, img_h)

            if left + w <= img_w and top + h <= img_h:
                break

        if pixel_level:
            if input_img.ndim == 3:
                c = np.random.uniform(v_l, v_h, (h, w, img_c))
            if input_img.ndim == 2:
                c = np.random.uniform(v_l, v_h, (h, w))
        else:
            c = np.random.uniform(v_l, v_h)

        input_img[top:top + h, left:left + w] = c

        return input_img
    

    return eraser

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

original_dir ="../input/total-cucumber-multi/Total_Cucumber_multi/Total_Cucumber"
total_data = pd.read_csv('../input/total-cucumber-multi/cucumber_3.csv')
labels = total_data[['label']]
names = total_data[['name']]
                         
stratkf = StratifiedKFold(n_splits = 3, random_state = 7, shuffle = True)


VAL_ACCURACIES = []
VAL_LOSSES = []

fold_count = 1


train_datagen = ImageDataGenerator(
    rescale = (1./255),
    rotation_range=90,
    width_shift_range=.2, 
    height_shift_range=.2,
    zoom_range = 0.2,
    brightness_range=(0.9,1.5),
    horizontal_flip=True,
    preprocessing_function=get_random_eraser(v_l=0, v_h=1))

#test_datagen = ImageDataGenerator(rescale = (1./255))
validation_datagen = ImageDataGenerator(rescale = (1./255))

# %%
def getModelName(i):
    return 'model_'+str(i)+'.h5'

# %%
import keras 
from keras.layers import Dense,Dropout, Conv2D,MaxPooling2D , Activation, Flatten
from keras.models import Sequential
from tensorflow.keras.layers import *
import math
import tensorflow as tf

# %%
for tr_index, val_index in stratkf.split(names,labels):
    training_data = total_data.iloc[tr_index]
    validation_data = total_data.iloc[val_index]



    train_generator = train_datagen.flow_from_dataframe(
        training_data,
        directory = original_dir,
        target_size=(224, 224),
        x_col = "name",
        y_col = "label",
        batch_size= 32,
        class_mode='categorical',
        shuffle=True)

    validation_generator = validation_datagen.flow_from_dataframe(
        validation_data,
        directory = original_dir,
        target_size=(224, 224),
        x_col = "name",
        y_col = "label",
        batch_size= 32,
        class_mode='categorical',
        shuffle=True)
    
    model = Sequential()

    model.add(Conv2D(input_shape=(224,224,3),filters=64,kernel_size=(3,3),padding="same", activation="relu"))
    model.add(Conv2D(filters=64,kernel_size=(3,3),padding="same", activation="relu"))

    model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))

    model.add(Conv2D(filters=128, kernel_size=(3,3),padding="same", activation="relu"))
    model.add(Conv2D(filters=128, kernel_size=(3,3),padding="same", activation="relu"))

    model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))

    model.add(Conv2D(filters=256, kernel_size=(3,3),padding="same", activation="relu"))
    model.add(Conv2D(filters=256, kernel_size=(3,3),padding="same", activation="relu"))
    model.add(Conv2D(filters=256, kernel_size=(3,3),padding="same", activation="relu"))

    model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))

    model.add(Conv2D(filters=512, kernel_size=(3,3),padding="same", activation="relu"))
    model.add(Conv2D(filters=512, kernel_size=(3,3),padding="same", activation="relu"))
    model.add(Conv2D(filters=512, kernel_size=(3,3),padding="same", activation="relu"))

    model.add(MaxPooling2D(pool_size=(2,2),strides=(2,2)))

    model.add(Conv2D(filters=512, kernel_size=(3,3),padding="same", activation="relu"))
    model.add(Conv2D(filters=512, kernel_size=(3,3),padding="same", activation="relu"))
    model.add(Conv2D(filters=512, kernel_size=(3,3),padding="same", activation="relu"))

    model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))

    model.add(Flatten())

    model.add(Dense(units=4096,activation="relu"))
    model.add(Dense(units=4096,activation="relu"))

    model.add(Dense(units=3, activation="softmax"))
    model.compile(optimizer= keras.optimizers.Adam(lr=0.00001), loss='binary_crossentropy', metrics=['accuracy'])
    model.summary()


    from keras.callbacks import ModelCheckpoint, EarlyStopping
    earlyStopping = EarlyStopping(monitor='val_loss', verbose=0, mode='min', patience = 6)
    mcp_save = ModelCheckpoint('./'+getModelName(fold_count), save_best_only=True, monitor='val_loss', mode='min')
    
    
    history = model.fit_generator(train_generator,
                use_multiprocessing=True,
                workers=6,
                steps_per_epoch=math.ceil(train_generator.n//train_generator.batch_size),
                epochs = 50,
                validation_steps=math.ceil(validation_generator.n//validation_generator.batch_size),
                callbacks=[earlyStopping, mcp_save],
                validation_data=validation_generator,)
    
    
    model.load_weights("./model_"+str(fold_count)+".h5")
    
    result = model.evaluate_generator(generator=validation_generator,
            steps=validation_generator.n//validation_generator.batch_size)
    print(result)
    
    result = dict(zip(model.metrics_names,result))

    VAL_ACCURACIES.append(result['accuracy'])
    VAL_LOSSES.append(result['loss'])
    tf.keras.backend.clear_session()
    fold_count += 1
# Out:
# Found 932 validated image filenames belonging to 3 classes.
# Found 466 validated image filenames belonging to 3 classes.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 224, 224, 64)      1792
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 224, 224, 64)      36928
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 112, 112, 128)     73856
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 112, 112, 128)     147584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 56, 56, 256)       295168
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 56, 56, 256)       590080
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 56, 56, 256)       590080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 256)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 28, 28, 512)       1180160
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 28, 28, 512)       2359808
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 28, 28, 512)       2359808
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 512)       0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              102764544
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 12291
# =================================================================
# Total params: 134,272,835
# Trainable params: 134,272,835
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 29/29 [==============================] - 42s 1s/step - loss: 0.5694 - accuracy: 0.5344 - val_loss: 0.5167 - val_accuracy: 0.8415
# Epoch 2/50
# 29/29 [==============================] - 43s 1s/step - loss: 0.5276 - accuracy: 0.5233 - val_loss: 0.5276 - val_accuracy: 0.5625
# Epoch 3/50
# 29/29 [==============================] - 46s 2s/step - loss: 0.5117 - accuracy: 0.5489 - val_loss: 0.4928 - val_accuracy: 0.6562
# Epoch 4/50
# 29/29 [==============================] - 49s 2s/step - loss: 0.4674 - accuracy: 0.6656 - val_loss: 0.3254 - val_accuracy: 0.9420
# Epoch 5/50
# 29/29 [==============================] - 47s 2s/step - loss: 0.2464 - accuracy: 0.8956 - val_loss: 0.1433 - val_accuracy: 0.9375
# Epoch 6/50
# 29/29 [==============================] - 53s 2s/step - loss: 0.1651 - accuracy: 0.9332 - val_loss: 0.1264 - val_accuracy: 0.9420
# Epoch 7/50
# 29/29 [==============================] - 47s 2s/step - loss: 0.1615 - accuracy: 0.9300 - val_loss: 0.1214 - val_accuracy: 0.9442
# Epoch 8/50
# 29/29 [==============================] - 38s 1s/step - loss: 0.1661 - accuracy: 0.9289 - val_loss: 0.1326 - val_accuracy: 0.9375
# Epoch 9/50
# 29/29 [==============================] - 45s 2s/step - loss: 0.1794 - accuracy: 0.9256 - val_loss: 0.1413 - val_accuracy: 0.9353
# Epoch 10/50
# 29/29 [==============================] - 42s 1s/step - loss: 0.1684 - accuracy: 0.9244 - val_loss: 0.1443 - val_accuracy: 0.9353
# Epoch 11/50
# 29/29 [==============================] - 39s 1s/step - loss: 0.1571 - accuracy: 0.9256 - val_loss: 0.1358 - val_accuracy: 0.9420
# Epoch 12/50
# 29/29 [==============================] - 38s 1s/step - loss: 0.1513 - accuracy: 0.9311 - val_loss: 0.1523 - val_accuracy: 0.9420
# Epoch 13/50
# 29/29 [==============================] - 39s 1s/step - loss: 0.1418 - accuracy: 0.9322 - val_loss: 0.1553 - val_accuracy: 0.9353
# [0.11942537128925323, 0.9441964030265808]
# Found 932 validated image filenames belonging to 3 classes.
# Found 466 validated image filenames belonging to 3 classes.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 224, 224, 64)      1792
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 224, 224, 64)      36928
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 112, 112, 128)     73856
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 112, 112, 128)     147584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 56, 56, 256)       295168
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 56, 56, 256)       590080
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 56, 56, 256)       590080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 256)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 28, 28, 512)       1180160
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 28, 28, 512)       2359808
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 28, 28, 512)       2359808
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 512)       0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              102764544
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 12291
# =================================================================
# Total params: 134,272,835
# Trainable params: 134,272,835
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 29/29 [==============================] - 56s 2s/step - loss: 0.5781 - accuracy: 0.5433 - val_loss: 0.5226 - val_accuracy: 0.5513
# Epoch 2/50
# 29/29 [==============================] - 49s 2s/step - loss: 0.5162 - accuracy: 0.5522 - val_loss: 0.5198 - val_accuracy: 0.5446
# Epoch 3/50
# 29/29 [==============================] - 46s 2s/step - loss: 0.5096 - accuracy: 0.6011 - val_loss: 0.4896 - val_accuracy: 0.5491
# Epoch 4/50
# 29/29 [==============================] - 51s 2s/step - loss: 0.4532 - accuracy: 0.7189 - val_loss: 0.3019 - val_accuracy: 0.9263
# Epoch 5/50
# 29/29 [==============================] - 49s 2s/step - loss: 0.2440 - accuracy: 0.8778 - val_loss: 0.1443 - val_accuracy: 0.9330
# Epoch 6/50
# 29/29 [==============================] - 52s 2s/step - loss: 0.1514 - accuracy: 0.9344 - val_loss: 0.1151 - val_accuracy: 0.9442
# Epoch 7/50
# 29/29 [==============================] - 45s 2s/step - loss: 0.1504 - accuracy: 0.9344 - val_loss: 0.1330 - val_accuracy: 0.9375
# Epoch 8/50
# 29/29 [==============================] - 47s 2s/step - loss: 0.1466 - accuracy: 0.9367 - val_loss: 0.1225 - val_accuracy: 0.9464
# Epoch 9/50
# 29/29 [==============================] - 61s 2s/step - loss: 0.1316 - accuracy: 0.9356 - val_loss: 0.1011 - val_accuracy: 0.9420
# Epoch 10/50
# 29/29 [==============================] - 47s 2s/step - loss: 0.1369 - accuracy: 0.9353 - val_loss: 0.1683 - val_accuracy: 0.9420
# Epoch 11/50
# 29/29 [==============================] - 41s 1s/step - loss: 0.1221 - accuracy: 0.9400 - val_loss: 0.1213 - val_accuracy: 0.9062
# Epoch 12/50
# 29/29 [==============================] - 46s 2s/step - loss: 0.1221 - accuracy: 0.9378 - val_loss: 0.1322 - val_accuracy: 0.9018
# Epoch 13/50
# 29/29 [==============================] - 45s 2s/step - loss: 0.1120 - accuracy: 0.9400 - val_loss: 0.0920 - val_accuracy: 0.9442
# Epoch 14/50
# 29/29 [==============================] - 40s 1s/step - loss: 0.1164 - accuracy: 0.9367 - val_loss: 0.1043 - val_accuracy: 0.9263
# Epoch 15/50
# 29/29 [==============================] - 55s 2s/step - loss: 0.1048 - accuracy: 0.9389 - val_loss: 0.0908 - val_accuracy: 0.9464
# Epoch 16/50
# 29/29 [==============================] - 44s 2s/step - loss: 0.1022 - accuracy: 0.9389 - val_loss: 0.0975 - val_accuracy: 0.9442
# Epoch 17/50
# 29/29 [==============================] - 44s 2s/step - loss: 0.1073 - accuracy: 0.9311 - val_loss: 0.1049 - val_accuracy: 0.9464
# Epoch 18/50
# 29/29 [==============================] - 50s 2s/step - loss: 0.0917 - accuracy: 0.9422 - val_loss: 0.0741 - val_accuracy: 0.9442
# Epoch 19/50
# 29/29 [==============================] - 40s 1s/step - loss: 0.1238 - accuracy: 0.9300 - val_loss: 0.0856 - val_accuracy: 0.9487
# Epoch 20/50
# 29/29 [==============================] - 41s 1s/step - loss: 0.1036 - accuracy: 0.9389 - val_loss: 0.1024 - val_accuracy: 0.9353
# Epoch 21/50
# 29/29 [==============================] - 43s 1s/step - loss: 0.0947 - accuracy: 0.9389 - val_loss: 0.0989 - val_accuracy: 0.9241
# Epoch 22/50
# 29/29 [==============================] - 42s 1s/step - loss: 0.1214 - accuracy: 0.9400 - val_loss: 0.1033 - val_accuracy: 0.9241
# Epoch 23/50
# 29/29 [==============================] - 41s 1s/step - loss: 0.1045 - accuracy: 0.9378 - val_loss: 0.1063 - val_accuracy: 0.9129
# Epoch 24/50
# 29/29 [==============================] - 40s 1s/step - loss: 0.0963 - accuracy: 0.9422 - val_loss: 0.1002 - val_accuracy: 0.9196
# [0.0817159041762352, 0.9375]
# Found 932 validated image filenames belonging to 3 classes.
# Found 466 validated image filenames belonging to 3 classes.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 224, 224, 64)      1792
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 224, 224, 64)      36928
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 112, 112, 128)     73856
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 112, 112, 128)     147584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 56, 56, 256)       295168
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 56, 56, 256)       590080
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 56, 56, 256)       590080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 256)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 28, 28, 512)       1180160
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 28, 28, 512)       2359808
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 28, 28, 512)       2359808
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 512)       0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              102764544
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 12291
# =================================================================
# Total params: 134,272,835
# Trainable params: 134,272,835
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 29/29 [==============================] - 45s 2s/step - loss: 0.5683 - accuracy: 0.5522 - val_loss: 0.5135 - val_accuracy: 0.5625
# Epoch 2/50
# 29/29 [==============================] - 42s 1s/step - loss: 0.5174 - accuracy: 0.5539 - val_loss: 0.5151 - val_accuracy: 0.5558
# Epoch 3/50
# 29/29 [==============================] - 51s 2s/step - loss: 0.4998 - accuracy: 0.5922 - val_loss: 0.4696 - val_accuracy: 0.7188
# Epoch 4/50
# 29/29 [==============================] - 49s 2s/step - loss: 0.3688 - accuracy: 0.7922 - val_loss: 0.1806 - val_accuracy: 0.9308
# Epoch 5/50
# 29/29 [==============================] - 47s 2s/step - loss: 0.1380 - accuracy: 0.9378 - val_loss: 0.1405 - val_accuracy: 0.9330
# Epoch 6/50
# 29/29 [==============================] - 45s 2s/step - loss: 0.1355 - accuracy: 0.9411 - val_loss: 0.1140 - val_accuracy: 0.9375
# Epoch 7/50
# 29/29 [==============================] - 41s 1s/step - loss: 0.1225 - accuracy: 0.9333 - val_loss: 0.1491 - val_accuracy: 0.9308
# Epoch 8/50
# 29/29 [==============================] - 40s 1s/step - loss: 0.1292 - accuracy: 0.9367 - val_loss: 0.1232 - val_accuracy: 0.9286
# Epoch 9/50
# 29/29 [==============================] - 59s 2s/step - loss: 0.1352 - accuracy: 0.9333 - val_loss: 0.1017 - val_accuracy: 0.9464
# Epoch 10/50
# 29/29 [==============================] - 45s 2s/step - loss: 0.1105 - accuracy: 0.9444 - val_loss: 0.1555 - val_accuracy: 0.8728
# Epoch 11/50
# 29/29 [==============================] - 44s 2s/step - loss: 0.1066 - accuracy: 0.9389 - val_loss: 0.1038 - val_accuracy: 0.9375
# Epoch 12/50
# 29/29 [==============================] - 40s 1s/step - loss: 0.0977 - accuracy: 0.9444 - val_loss: 0.1080 - val_accuracy: 0.9219
# Epoch 13/50
# 29/29 [==============================] - 46s 2s/step - loss: 0.0963 - accuracy: 0.9489 - val_loss: 0.1227 - val_accuracy: 0.9040
# Epoch 14/50
# 29/29 [==============================] - 42s 1s/step - loss: 0.0935 - accuracy: 0.9500 - val_loss: 0.1088 - val_accuracy: 0.9174
# Epoch 15/50
# 29/29 [==============================] - 54s 2s/step - loss: 0.0910 - accuracy: 0.9411 - val_loss: 0.0998 - val_accuracy: 0.9286
# Epoch 16/50
# 29/29 [==============================] - 42s 1s/step - loss: 0.0906 - accuracy: 0.9533 - val_loss: 0.1247 - val_accuracy: 0.8951
# Epoch 17/50
# 29/29 [==============================] - 45s 2s/step - loss: 0.1061 - accuracy: 0.9300 - val_loss: 0.1058 - val_accuracy: 0.9420
# Epoch 18/50
# 29/29 [==============================] - 40s 1s/step - loss: 0.0854 - accuracy: 0.9478 - val_loss: 0.1001 - val_accuracy: 0.9196
# Epoch 19/50
# 29/29 [==============================] - 42s 1s/step - loss: 0.0854 - accuracy: 0.9533 - val_loss: 0.1102 - val_accuracy: 0.8951
# Epoch 20/50
# 29/29 [==============================] - 50s 2s/step - loss: 0.0915 - accuracy: 0.9478 - val_loss: 0.0890 - val_accuracy: 0.9397
# Epoch 21/50
# 29/29 [==============================] - 40s 1s/step - loss: 0.0799 - accuracy: 0.9522 - val_loss: 0.0945 - val_accuracy: 0.9263
# Epoch 22/50
# 29/29 [==============================] - 41s 1s/step - loss: 0.0874 - accuracy: 0.9411 - val_loss: 0.0901 - val_accuracy: 0.9375
# Epoch 23/50
# 29/29 [==============================] - 40s 1s/step - loss: 0.1038 - accuracy: 0.9244 - val_loss: 0.1347 - val_accuracy: 0.8638
# Epoch 24/50
# 29/29 [==============================] - 44s 2s/step - loss: 0.0803 - accuracy: 0.9456 - val_loss: 0.0954 - val_accuracy: 0.9241
# Epoch 25/50
# 29/29 [==============================] - 41s 1s/step - loss: 0.0844 - accuracy: 0.9411 - val_loss: 0.1041 - val_accuracy: 0.8929
# Epoch 26/50
# 29/29 [==============================] - 45s 2s/step - loss: 0.0882 - accuracy: 0.9378 - val_loss: 0.0949 - val_accuracy: 0.9308
# [0.08898355811834335, 0.9375]

# %%
avg_acc = sum(VAL_ACCURACIES)/len(VAL_ACCURACIES)
avg_loss = sum(VAL_LOSSES)/len(VAL_LOSSES)
for i in range(3):
    print("Validation Accuracy for  Fold = "+ str(i)+" is "+str(VAL_ACCURACIES[i]*100) +"  and Loss = "+str(VAL_LOSSES[i]))
    
print("Average Accuracy = "+ str(i)+" is "+str(avg_acc*100) +"  and Average Loss = "+str(avg_loss))
# Out:
# Validation Accuracy for  Fold = 0 is 94.41964030265808  and Loss = 0.11942537128925323
# Validation Accuracy for  Fold = 1 is 93.75  and Loss = 0.0817159041762352
# Validation Accuracy for  Fold = 2 is 93.75  and Loss = 0.08898355811834335
# Average Accuracy = 2 is 93.97321343421936  and Average Loss = 0.09670827786127727

# %%
# import matplotlib.pyplot as plt

# plt.plot(history.epoch,history.history['val_accuracy'],'-b',label='Validation Accuracy')
# plt.plot(history.epoch,history.history['accuracy'],'-g',label='Training Accuracy')

# plt.title('Training and Validation Accuracy')
# plt.xlabel('Epochs')
# plt.ylabel('Accuracy')
# plt.legend()
# plt.show()

# # print(history.history['va'])
# loss_train = history.history['loss']
# loss_val = history.history['val_loss']
# epochs = history.epoch
# plt.plot(epochs, loss_train, 'g', label='Training loss')
# plt.plot(epochs, loss_val, 'b', label='validation loss')
# plt.title('Training and Validation loss')
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# plt.legend()
# plt.show()

# %%
# model.load_weights("./rottenvsfresh_apple.h5")

# %%
# testing_generator = test_datagen.flow_from_directory(
#     '../input/apples7030/Apples/test',
#     target_size=(224, 224),
#     batch_size= 1,
#     class_mode='binary',
#     shuffle=False)
# STEP_SIZE_TEST=testing_generator.n
# print(STEP_SIZE_TEST)
# # valid_generator.reset()
# pred=model.predict_generator(testing_generator,
# steps=STEP_SIZE_TEST,
# verbose=1)

# %%
# orignal_labels=testing_generator.labels

# %%
# # #print(np.sum(orignal_labels))
# for i in range(len(pred)):
#     if pred[i]>0.5:
#         pred[i]=1
#     else:
#         pred[i]=0
# pred=pred[:,0]

# %%
# # predicted_class_indices=np.argmax(pred,axis=1)
# # print(predicted_class_indices)

# labels = (testing_generator.class_indices)

# labels = dict((v,k) for k,v in labels.items())

# predictions = [labels[k] for k in list(pred)]

# #print(predictions)
# filenames=testing_generator.filenames
# results=pd.DataFrame({"Filename":filenames,
#                       "Predictions":predictions})

# print(results)

# %%
# acc=np.sum(np.array(orignal_labels)==np.array(pred))
# print("Prediction Accuracy = ",acc/len(orignal_labels))
